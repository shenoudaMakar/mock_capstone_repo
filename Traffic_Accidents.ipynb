# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime


# %matplotlib inline

# %%
Traffic_Accidents_df = pd.read_csv("Traffic_Accidents.csv")
# Out:
# C:\Users\sheno\AppData\Local\Temp\ipykernel_37980\743189976.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Traffic_Accidents_df = pd.read_csv("Traffic_Accidents.csv")

# %%
Traffic_Accidents_df.head()
# Out:
#    Accident Number                Date and Time  Number of Motor Vehicles  \
# 0      20200606233  September 21, 2020 06:37 PM                       1.0
# 1      20200603908  September 20, 2020 12:00 AM                       1.0
# 2      20200604395  September 20, 2020 07:20 PM                       1.0
# 3      20200605021  September 21, 2020 05:58 AM                       2.0
# 4      20200605988  September 21, 2020 03:27 PM                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                   0                     0             NaN       False
# 1                   0                     0            True        True
# 2                   1                     0             NaN       False
# 3                   0                     0             NaN       False
# 4                   0                     0             NaN       False
#
#    Reporting Officer  Collision Type Code  \
# ...

# %%
Traffic_Accidents_df.columns
# Out:
# Index(['Accident Number', 'Date and Time', 'Number of Motor Vehicles',
#        'Number of Injuries', 'Number of Fatalities', 'Property Damage',
#        'Hit and Run', 'Reporting Officer', 'Collision Type Code',
#        'Collision Type Description', 'Weather Code', 'Weather Description',
#        'Illumination Code', 'Illumination Description', 'Harmful Code',
#        'Harmful Description', 'Street Address', 'City', 'State', 'ZIP', 'RPA',
#        'Precinct', 'Latitude', 'Longitude', 'Mapped Location'],
#       dtype='object')

# %%
Traffic_Accidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220118 entries, 0 to 220117
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             220118 non-null  int64
#  1   Date and Time               220118 non-null  object
#  2   Number of Motor Vehicles    220117 non-null  float64
#  3   Number of Injuries          220118 non-null  int64
#  4   Number of Fatalities        220118 non-null  int64
#  5   Property Damage             16254 non-null   object
#  6   Hit and Run                 220101 non-null  object
#  7   Reporting Officer           220108 non-null  float64
#  8   Collision Type Code         220101 non-null  float64
#  9   Collision Type Description  220101 non-null  object
#  10  Weather Code                214737 non-null  float64
#  11  Weather Description         214737 non-null  object
# ...

# %%
Traffic_Accidents_df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           1
# Number of Injuries                 0
# Number of Fatalities               0
# Property Damage               203864
# Hit and Run                       17
# Reporting Officer                 10
# Collision Type Code               17
# Collision Type Description        17
# Weather Code                    5381
# Weather Description             5381
# Illumination Code                310
# Illumination Description         310
# Harmful Code                       0
# Harmful Description             2324
# Street Address                     8
# City                               0
# State                              0
# ZIP                             1100
# RPA                             1106
# Precinct                        1122
# Latitude                         481
# Longitude                        481
# Mapped Location                  481
# dtype: int64

# %%
Traffic_Accidents_df.nunique()
# Out:
# Accident Number               220118
# Date and Time                 197171
# Number of Motor Vehicles          14
# Number of Injuries                16
# Number of Fatalities               1
# Property Damage                    1
# Hit and Run                        2
# Reporting Officer               1535
# Collision Type Code               10
# Collision Type Description        10
# Weather Code                      12
# Weather Description               12
# Illumination Code                  8
# Illumination Description           8
# Harmful Code                    3605
# Harmful Description             2790
# Street Address                 28988
# City                              19
# State                              1
# ZIP                               33
# RPA                             1944
# Precinct                           8
# Latitude                        3340
# Longitude                       4025
# Mapped Location                25764
# dtype: int64

# %%
Traffic_Accidents_df
# Out:
#         Accident Number                Date and Time  \
# 0           20200606233  September 21, 2020 06:37 PM
# 1           20200603908  September 20, 2020 12:00 AM
# 2           20200604395  September 20, 2020 07:20 PM
# 3           20200605021  September 21, 2020 05:58 AM
# 4           20200605988  September 21, 2020 03:27 PM
# ...                 ...                          ...
# 220113      20210529661    October 10, 2021 08:53 PM
# 220114      20210529129    October 10, 2021 01:24 AM
# 220115      20210529262    October 10, 2021 02:30 PM
# 220116      20210529382    October 10, 2021 12:00 AM
# 220117      20210528648    October 10, 2021 02:00 AM
#
#         Number of Motor Vehicles  Number of Injuries  Number of Fatalities  \
# 0                            1.0                   0                     0
# 1                            1.0                   0                     0
# 2                            1.0                   1                     0
# ...

# %%
Traffic_Accidents_df.describe()
# Out:
#        Accident Number  Number of Motor Vehicles  Number of Injuries  \
# count     2.201180e+05             220117.000000       220118.000000
# mean      2.017933e+10                  1.851247            0.389959
# std       2.024968e+07                  0.692973            0.762556
# min       2.010081e+10                  0.000000            0.000000
# 25%       2.016080e+10                  2.000000            0.000000
# 50%       2.018032e+10                  2.000000            0.000000
# 75%       2.019081e+10                  2.000000            1.000000
# max       2.022038e+10                 27.000000           35.000000
#
#        Number of Fatalities  Reporting Officer  Collision Type Code  \
# count              220118.0       2.201080e+05        220101.000000
# mean                    0.0       4.911680e+05             7.219036
# std                     0.0       7.277035e+05            10.697676
# min                     0.0       1.000000e+00             0.000000
# ...

# %%
Traffic_Accidents_df.isnull().any()
# Out:
# Accident Number               False
# Date and Time                 False
# Number of Motor Vehicles       True
# Number of Injuries            False
# Number of Fatalities          False
# Property Damage                True
# Hit and Run                    True
# Reporting Officer              True
# Collision Type Code            True
# Collision Type Description     True
# Weather Code                   True
# Weather Description            True
# Illumination Code              True
# Illumination Description       True
# Harmful Code                  False
# Harmful Description            True
# Street Address                 True
# City                          False
# State                         False
# ZIP                            True
# RPA                            True
# Precinct                       True
# Latitude                       True
# Longitude                      True
# Mapped Location                True
# dtype: bool

# %%
Traffic_Accidents_df
# Out:
#         Accident Number                Date and Time  \
# 0           20200606233  September 21, 2020 06:37 PM
# 1           20200603908  September 20, 2020 12:00 AM
# 2           20200604395  September 20, 2020 07:20 PM
# 3           20200605021  September 21, 2020 05:58 AM
# 4           20200605988  September 21, 2020 03:27 PM
# ...                 ...                          ...
# 220113      20210529661    October 10, 2021 08:53 PM
# 220114      20210529129    October 10, 2021 01:24 AM
# 220115      20210529262    October 10, 2021 02:30 PM
# 220116      20210529382    October 10, 2021 12:00 AM
# 220117      20210528648    October 10, 2021 02:00 AM
#
#         Number of Motor Vehicles  Number of Injuries  Number of Fatalities  \
# 0                            1.0                   0                     0
# 1                            1.0                   0                     0
# 2                            1.0                   1                     0
# ...

# %%
Traffic_Accidents_df.dropna()
# Out:
#         Accident Number                Date and Time  \
# 1           20200603908  September 20, 2020 12:00 AM
# 20          20200605611  September 21, 2020 12:30 PM
# 27          20200604135  September 20, 2020 06:55 PM
# 44          20200603888  September 20, 2020 03:20 PM
# 63          20200604189  September 20, 2020 06:41 PM
# ...                 ...                          ...
# 220072      20210529663    October 10, 2021 08:50 PM
# 220075      20210528356    October 09, 2021 09:45 PM
# 220091      20210528573    October 09, 2021 10:00 PM
# 220100      20210529669    October 10, 2021 09:00 PM
# 220106      20210528797    October 10, 2021 12:00 AM
#
#         Number of Motor Vehicles  Number of Injuries  Number of Fatalities  \
# 1                            1.0                   0                     0
# 20                           2.0                   0                     0
# 27                           1.0                   0                     0
# ...

# %%
# Numbers of hit and run by city.

# %%
number_of_vehicles = Traffic_Accidents_df[['Hit and Run','City','Harmful Description']]
number_of_vehicles
# Out:
#        Hit and Run         City  \
# 0            False    NASHVILLE
# 1             True    NASHVILLE
# 2            False  OLD HICKORY
# 3            False    NASHVILLE
# 4            False    NASHVILLE
# ...            ...          ...
# 220113       False    NASHVILLE
# 220114        True    NASHVILLE
# 220115       False    NASHVILLE
# 220116       False      ANTIOCH
# 220117        True    HERMITAGE
#
#                                       Harmful Description
# 0                                  TREE;Ran Off Road-Left
# 1                                                MAIL BOX
# 2                                            OTHER ANIMAL
# 3                              MOTOR VEHICLE IN TRANSPORT
# 4                              MOTOR VEHICLE IN TRANSPORT
# ...                                                   ...
# 220113            MOTOR VEHICLE IN TRANSPORT;UTILITY POLE
# 220114                               PARKED MOTOR VEHICLE
# ...

# %%
Accidents = Traffic_Accidents_df[['Number of Injuries','City','Harmful Description']].value_counts().head()
number_of_vehicles
# Out:
# Number of Injuries  City       Harmful Description
# 0                   NASHVILLE  MOTOR VEHICLE IN TRANSPORT    90512
# 1                   NASHVILLE  MOTOR VEHICLE IN TRANSPORT    22240
# 0                   ANTIOCH    MOTOR VEHICLE IN TRANSPORT    10397
#                     MADISON    MOTOR VEHICLE IN TRANSPORT     7695
# 2                   NASHVILLE  MOTOR VEHICLE IN TRANSPORT     6731
# dtype: int64

# %%
Traffic_Accidents_df['City'].value_counts().head(5)
# Out:
# NASHVILLE    165583
# ANTIOCH       21513
# MADISON       14355
# HERMITAGE      7536
# BRENTWOOD      3671
# Name: City, dtype: int64

# %%
Traffic_Accidents_df['Hit and Run'].count()
# Out:
# 220101

# %%
# Which city has the highest accidents rates?

# %%
city_count = Traffic_Accidents_df[['Accident Number','City']].value_counts().head(5)
city_count
# Out:
# Accident Number  City
# 20100808802      NASHVILLE         1
# 20190329403      NASHVILLE         1
# 20190329417      GOODLETTSVILLE    1
# 20190329427      ANTIOCH           1
# 20190329432      NASHVILLE         1
# dtype: int64

# %%
#count of accidentsf by weather conditions

# %%
counts = Traffic_Accidents_df.groupby(['Weather Description']).count()['City']
counts = counts.reset_index()
counts
# Out:
#        Weather Description    City
# 0   BLOWING SAND/SOIL/DIRT       1
# 1             BLOWING SNOW      82
# 2                    CLEAR  149633
# 3                   CLOUDY   31705
# 4                      FOG     451
# 5        OTHER (NARRATIVE)     120
# 6                     RAIN   28504
# 7         SEVERE CROSSWIND      28
# 8              SLEET, HAIL     396
# 9              SMOG, SMOKE      25
# 10                    SNOW    1748
# 11                 UNKNOWN    2044

# %%
# get top 5 city by yearly hit and run rate
top_city_df=Traffic_Accidents_df[['City', 'Hit and Run']].sort_values('Hit and Run',ascending=False, ignore_index=True)[:5]
top_city_df
# Out:
#         City Hit and Run
# 0  NASHVILLE        True
# 1  NASHVILLE        True
# 2  NASHVILLE        True
# 3  NASHVILLE        True
# 4    MADISON        True

# %%
injuries_df = Traffic_Accidents_df.groupby(Traffic_Accidents_df['City']).count().sort_values(by = 'State', ascending = False).head(5)
injuries_df = injuries_df.reset_index()
injuries_df = injuries_df[['City', 'State']]
injuries_df = injuries_df.rename(columns={'State' : 'State', 'City': 'Count'})
injuries_df
# Out:
#        Count   State
# 0  NASHVILLE  165583
# 1    ANTIOCH   21513
# 2    MADISON   14355
# 3  HERMITAGE    7536
# 4  BRENTWOOD    3671

# %%
Traffic_Accidents_df["Date and Time"]
# Out:
# 0         September 21, 2020 06:37 PM
# 1         September 20, 2020 12:00 AM
# 2         September 20, 2020 07:20 PM
# 3         September 21, 2020 05:58 AM
# 4         September 21, 2020 03:27 PM
#                      ...
# 220113      October 10, 2021 08:53 PM
# 220114      October 10, 2021 01:24 AM
# 220115      October 10, 2021 02:30 PM
# 220116      October 10, 2021 12:00 AM
# 220117      October 10, 2021 02:00 AM
# Name: Date and Time, Length: 220118, dtype: object
